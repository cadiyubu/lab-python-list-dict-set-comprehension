# %% [markdown]
# # Lab | List, Dict and Set Comprehension

# %% [markdown]
# ## Exercise: Managing Customer Orders Optimized with Comprehension

# %% [markdown]
# In the previous exercise, you developed a program to manage customer orders and inventory. Now, let's take it a step further and incorporate comprehension into your code.
#
# Follow the steps below to complete the exercise:
#
# 1. Review your code from the previous exercise and identify areas where you can apply comprehension to simplify and streamline your code.
#
#     - *Hint: Apply it to initialize inventory, updating the inventory and printing the updated inventory.*
#
#     - For example, in initializing the inventory, we could have:
#
#         ```python
#         def initialize_inventory(products):
#             inventory = {product: int(input(f"Enter the quantity of {product}s available: ")) for product in products}
#             return inventory
#
#         ```
# <br>
#
#
# 2. Modify the function get_customer_orders so it prompts the user to enter the number of customer orders and gathers the product names using a loop and user input. Use comprehension.
#
# 3. Add a new function to calculate the total price of the customer order. For each product in customer_orders, prompt the user to enter the price of that product. Use comprehension to calculate the total price. Note: assume that the user can only have 1 unit of each product.
#
# 4. Modify the update_inventory function to remove the product from the inventory if its quantity becomes zero after fulfilling the customer orders. Use comprehension to filter out the products with a quantity of zero from the inventory.
#
# 5. Print the total price of the customer order.
#
# Your code should produce output similar to the following:
#
# ```python
# Enter the quantity of t-shirts available:  5
# Enter the quantity of mugs available:  4
# Enter the quantity of hats available:  3
# Enter the quantity of books available:  2
# Enter the quantity of keychains available:  1
# Enter the number of customer orders:  2
# Enter the name of a product that a customer wants to order:  hat
# Enter the name of a product that a customer wants to order:  keychain
#
# Order Statistics:
# Total Products Ordered: 2
# Percentage of Unique Products Ordered: 40.0
#
# Updated Inventory:
# t-shirt: 5
# mug: 4
# hat: 2
# book: 2
# Enter the price of keychain:  5
# Enter the price of hat:  10
# Total Price: 15.0
#
# ```

# %%
#1.identify areas where you can apply comprehension to simplify

# %%
def initialize_inventory(products):
    products=products.split(",")
    products=[prod.strip() for prod in products]
    inventory = {item: int(input(f"Enter the quantity of {item} available: ")) for item in products}
    return inventory

# %%
#2.Modify the function get_customer_orders so it prompts the user to 
#enter the number of customer orders and gathers the product names 
#using a loop and user input. Use comprehension.

# %%
def get_customer_orders():
    n=int(input("Enter the number of orders that you want:"))
    customer_orders=set()
    customer_orders={input("Type the name of the product you want:") for n in range(n+1) if n>0}
    return customer_orders

# %%
#3. Add a new function to calculate the total price of the customer order. For each product in 
#customer_orders, prompt the user to enter the price of that product. Use comprehension to calculate
#the total price. Note: assume that the user can only have 1 unit of each product.

# %%
def total_price_order():
    order_item= customer_orders
    price_list=[float(input(f"What is the price of {item} :?")) for item in order_item]
    total=sum(price_list)
    return f"The total price of your items is {total}"

# %%
#4.Modify the update_inventory function to remove the product from the inventory if its quantity 
#becomes zero after fulfilling the customer orders. Use comprehension to filter out the products with 
#a quantity of zero from the inventory.

def update_inventory(customer_orders, inventory):
    up_inventory = {item: (inventory[item]-1 if item in customer_orders and inventory[item]>0 else inventory[item] )
                     for item in inventory.keys() if inventory[item]>0}
    up_invent={item: value for item,value in up_inventory.items() if value>0 }
    return print(f"The updated inventory is:\n {up_invent}")

# %%
def calculate_order_statistics(customer_orders,products):
    total_products_ordered= len(customer_orders)
    count=0
    prod=list(products)
    for x in prod:
        count+=1
    
    perc_prod_ordered= (total_products_ordered/count)*100
    return total_products_ordered, perc_prod_ordered

# %%
def print_order_statistics(order_statistics):
    x=order_statistics[0]
    y=order_statistics[1]
    return print(f"Order statistics:\n the total of products ordered is :{x}\n the percentage of unique products ordered is; {y}")

# %%
inventory=initialize_inventory('t-shirts, mugs, hats, books, keys')
products=inventory.keys()
customer_orders= get_customer_orders()
order_statistics= calculate_order_statistics(customer_orders,products)
print_order_statistics(order_statistics)
update_inventory(customer_orders, inventory)
total_price_order()
# Out:
# Enter the quantity of t-shirts available:  2
# Enter the quantity of mugs available:  1
# Enter the quantity of hats available:  2
# Enter the quantity of books available:  1
# Enter the quantity of keys available:  2
# Enter the number of orders that you want: 1
# Type the name of the product you want: mugs
# Order statistics:
#  the total of products ordered is :1
#  the percentage of unique products ordered is; 20.0
# The updated inventory is:
#  {'t-shirts': 2, 'hats': 2, 'books': 1, 'keys': 2}
# What is the price of mugs :? 23
# 'The total price of your items is 23.0'
